# %% [markdown]
# # Loops
#
# ### WHILE LOOPS
# The While loop can execute a set of statements as long as a condition is true.
#
# A while loop will repeatedly execute a single statement or group of statements as long as the condition being checked is true. The reason it is called a 'loop' is because the code statements are looped through over and over again until the condition is no longer met.
#
# Code indentation becomes very important as we begin to work with loops.

# %%
g = 1

while g > 6:
    print("g is greater than 6")
    g = g + 1

# %%
# Start by initialising variable a to 0
a = 0

while a < 3:
    print('A is currently')
    print(a)
    print("Adding 1 to a")
    a = a + 1 #alternatively you could write a += 1

# %% [markdown]
# ____
# #### Note This!
# Be careful with while loops! There is a potential to write a condition that always remains True, meaning you have an infinite running while loop. If this happens to you, you can stop/restart the kernel.

# %% [markdown]
# # break statement

# %% [markdown]
# The break statement stop the loop even if the condition is true
# The break keyword allows you to "break" out of the loop that contains the break keyword. For example

# %%
b = 0

while b < 10:
    print(b)
    print('adding one to b')
    b = b + 1
    
    if b == 3:
        # This will cause to break out of the top loop 
        # Note that if statements don't count as loops
        break

# %% [markdown]
# ## The else statement****

# %% [markdown]
# The else statement can run a block of code once when the condition is no longer true

# %%
c = 1
while c<6:
    print(c)
    c = c + 1
    else:
        print("c is no longer lesser than 6")

# %% [markdown]
# # for loop
#
# A **for loop** acts as an iterator in Python, it goes through items that are in a sequence or any other iterable item. Objects that we've learned about that we can iterate over include strings,lists,tuples, and even built in iterables for dictionaries, such as the keys or values.
#
# A for loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).
#
# Here's the general format/syntax for a for loop in Python:
#
#     for item in object:
#         statements to do stuff
#
# The variable name used for the item is completely up to the coder, so use your best judgment for choosing a name that makes sense and you will be able to understand when revisiting your code.

# %% [markdown]
# ## for loop with a list

# %%
mylist = [1,2,3,4]

for num in mylist:
    print(num**2)

# %%
for totally_made_up in mylist:
    print(totally_made_up)

# %%
for num in mylist:
    print(num,end=' ')

# %%
for num in mylist:
    print("I am in a for loop")

# %% [markdown]
# ## for loop with strings

# %%
for character in "This is a string":
    print(character )

# %%
mystring = 'This is a string'

for word in mystring.split():
    print(word)

# %% [markdown]
# ## for loop with tuple

# %%
tup = (1,2,3,4)

for num in tup:
    print(num)
# Out:
# 1
# 2
# 3
# 4
