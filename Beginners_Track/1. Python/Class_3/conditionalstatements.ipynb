# %% [markdown]
# # CONDITIONAL STATEMENTS
#
# **CONDITIONAL STATEMENT**
# A conditional statement is a set of rules performed if a certain condition is met. Most times it is referred to as IF-ELSE or IF-THEN statements, that is IF it is not a THEN it is b
#
# **Example** --> We want to know if tayo is a male or female then we give boxers or wrapper respectively
# .
# IF tayo is a male give him boxers
# ELSE tayo is a female give her wrapper
#
# so simple and easy right. let us go into Conditional Statements in Python

# %% [markdown]
# # Conditional Statements in Python
#
# There are majorly three conditional statements in python and they are;
#
# **1. if Statement**
#
# **2. if else Statement**
#
# **3. elif Statement**
#
# **4. else Statement**
#
# Majority of the time when programming, we'll need to control the flow of our logic. Our program will want to perform an action in only certain cases, we can use the **if**, **elif**, and **else** statements to control for these cases.
# ### if Statement
# **if** statement is a programming coditional statement that if proven true it performs a function or displays an information.
#
# **Let us check out some of the examples below**

# %% [markdown]
# ## Simple if Statement
# The format/Syntax for an if statement
#
#     if some_condition:
#         # Do Something

# %%
if taiwo<shola:
    print('Taiwo is lesser than Shola')
# Out:
# One is less than two

# %%
if shola>taiwo:
    print("Shola is greater than Taiwo")

# %% [markdown]
# Notice what happens, the indented block of code only runs when the if condition is True!
# First of all what is **indentation**
#
# ### INDENTATION
# Indentation are four white space at the beginning of a line to define scope in the code. Python makes use of identation to define it scope while other languages often make use of curly brackets for this purpose.
#
# **Example**
# if a===b:
#     #code... this is a python if statement showing identation
#
# #if (a==b){
# #code...
# }

# %% [markdown]
# ## if else Statement
#
# Let's now add in an alternate action in case the **if** is not True using the **else** statement.
#
# Notice the format and how the code blocks line up, this is crucial in Python! Code indentation let's Python know what blocks and statements correspond together.
#
# Note: Always take note of identation as it could cause a major disaster while running your code though it is easy to spot

# %%
if 1==1:
    print("One is equal to One")
else:
    print("First if was not True")
# Out:
# One is equal to One

# %%
if 1==2:
    print("One is equal to Two")
else:
    print("First if was not True")
# Out:
# First if was not True

# %%
saved_password = 123456
new_password = input("Enter your password")

if int(new_password) == saved_password:
    print("Password correct")
else:
    print("You're a criminal")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# /opt/conda/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     812         try:
# --> 813             msg_list = socket.recv_multipart(mode, copy=copy)
#     814         except zmq.ZMQError as e:
#
# /opt/conda/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# ...

# %% [markdown]
# ## elif Statement
#
# Now let's imagine we have multiple conditions to check before the final **else** statement, this is where we can use the **elif** keyword to check for as many individual conditions as necessary:

# %%
if 2 == 0:
    print('First condition True')
elif 2 == 1:
    print("Second condition True")
elif 2 == 100:
    print("Third condition True")
else:
    print("None of the above conditions were True")

# %% [markdown]
# Let's see what happens if we had multiple True conditions:

# %%
if 2 == 2:
    print('First condition True')
elif 2 == 2:
    print("Second condition True")
elif 2 == 2:
    print("Third condition True")
else:
    print("None of the above conditions were True")

# %% [markdown]
# Notice how only the first True condition's code block will be executed, keep this in mind when writing your scripts!

# %% [markdown]
# Kindly visit https://w3schools.com for more resource on Python coditional statements
